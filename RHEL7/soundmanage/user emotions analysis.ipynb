# %%
import matplotlib.pyplot as plt

# %%
import pandas , numpy

# %%
import plotly, seaborn as sns

# %%
data=pandas.read_csv('/root/Desktop/music/user_data.csv')

# %%
data

# %%
sns.pairplot(data=data)

# %%
sns.jointplot(data=data,x='Happy',y='Time')
# Out:
# /usr/local/lib64/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-34edc20a195c> in <module>()
# ----> 1 sns.jointplot(data=data,x='Happy',y='Time')
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2249         marginal_kws.setdefault("kde", False)
#    2250         marginal_kws.setdefault("color", color)
# -> 2251         grid.plot_marginals(distplot, **marginal_kws)
#    2252
#    2253     elif kind.startswith("hex"):
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in plot_marginals(self, func, **kwargs)
# ...

# %%
sns.jointplot(data=data,x='Sad',y='Time')
# Out:
# /usr/local/lib64/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-83bb86108409> in <module>()
# ----> 1 sns.jointplot(data=data,x='Sad',y='Time')
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2249         marginal_kws.setdefault("kde", False)
#    2250         marginal_kws.setdefault("color", color)
# -> 2251         grid.plot_marginals(distplot, **marginal_kws)
#    2252
#    2253     elif kind.startswith("hex"):
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in plot_marginals(self, func, **kwargs)
# ...

# %%
sns.jointplot(data=data,x='Angry',y='Time')
# Out:
# /usr/local/lib64/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-187729815a46> in <module>()
# ----> 1 sns.jointplot(data=data,x='Angry',y='Time')
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2249         marginal_kws.setdefault("kde", False)
#    2250         marginal_kws.setdefault("color", color)
# -> 2251         grid.plot_marginals(distplot, **marginal_kws)
#    2252
#    2253     elif kind.startswith("hex"):
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in plot_marginals(self, func, **kwargs)
# ...

# %%
sns.jointplot(data=data,x='Fear',y='Time')
# Out:
# /usr/local/lib64/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1b210b07f403> in <module>()
# ----> 1 sns.jointplot(data=data,x='Fear',y='Time')
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2249         marginal_kws.setdefault("kde", False)
#    2250         marginal_kws.setdefault("color", color)
# -> 2251         grid.plot_marginals(distplot, **marginal_kws)
#    2252
#    2253     elif kind.startswith("hex"):
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in plot_marginals(self, func, **kwargs)
# ...

# %%
sns.swarmplot(data=data)
